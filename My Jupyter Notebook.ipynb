# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Salim Suhet Mussi**
#
# Electrical engeneer and Data science enthusiast.

# %% [markdown]
# *I am preparing for the future. Data science is definitely in the future.*

# %% [markdown]
# ### The next define a function to calculate a simple math operation:

# %%
import math
def add(a,b):
    return a + b
print("The addition of 1 plus 1 is:\n1 + 1 =", add(1,1))
# Out:
# The addition of 1 plus 1 is:
# 1 + 1 = 2

# %% [markdown]
# ***
#
# The simple math operation in python are:
# 1. Addition (Finding the Sum; '+')
# 2. Subtraction (Finding the difference; '-')
# 3. Multiplication (Finding the product; '×' )
# 4. Division (Finding the quotient; '/')
#
# ***
#
# But there are others operations as:
# * Floor division (Finding the floor divisiton; '/')
# * Modulus (Finding the remainder when first operand is divided by the second; '%')
# * Exponentiation (Findin the exponentiation; '**')
#
# ***
#
# | Operator | Name           | Example |
# |----------|----------------|---------|
# | +        | Addition       | x + y   |
# | -        | Subtraction    | x - y   |
# | *        | Multiplication | x * y   |
# | /        | Division       | x / y   |
# | //       | Floor Division | x // y  |
# | %        | Modulus        | x % y   |
# | **       | Exponentiation | x ** y  |
#
#
# Another mathematical functions are in [math library][1].
#
# [1]: https://docs.python.org/3/library/math.html
#
# ***
#
# `Try it!`
#
# ```python
# import math      #importing math library
# def sub(a,b):    #defining subtraction function
#     return a-b   #returning the result
# sub(2-1)         #using the function sub(a,b)
# ```
#
# ***
#
# [![Python logo](https://wiki.python.org/wiki/europython/img/python-logo.gif "Python logo")](https://www.python.org/)
#
# >"Python makes us extremely productive, and makes maintaining a large and rapidly evolving codebase relatively simple."
#
#     - Mark Shuttleworth.
#
# ~~ The end! ~~
